# %%
# !pip install -qU langchain sentence_transformers groq
# !pip install -qU langchain-huggingface langchain-community
# !pip install -qU faiss-cpu openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.7/268.7 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.9/108.9 kB 5.7 MB/s eta 0:00:00
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /packages/7e/ff/a1eacd78b31e52a5073e9924fb4722ecc2a72f093ca8181ed81fc61aed2e/SQLAlchemy-2.0.35-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 47.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 kB 24.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.6/389.6 kB 17.0 MB/s eta 0:00:00

# %%
from collections import Counter
from groq import Groq
from tqdm import tqdm
import numpy as np
import json
import faiss
import json
import pandas as pd
from openai import OpenAI
import os

from google.colab import drive, files

drive.mount('/content/drive', force_remount=True)

#API_KEY =
API_KEY =
#API_KEY =

client = Groq(
    api_key=API_KEY,
)

model_llm = "llama3-70b-8192"

os.environ["OPENAI_API_KEY"] = ""

client = OpenAI(
    # This is the default and can be omitted
    api_key=os.environ.get("OPENAI_API_KEY"),
)
# Out:
# Mounted at /content/drive

# %%
csv_path = '/content/drive/MyDrive/ProjetoFinal 2/df/df_questions_answers.xlsx'

data_csv = pd.read_excel(csv_path)
data_csv.head()
# Out:
#    question_number                               question_summary  \
# 0                1                                OBRIGATORIEDADE
# 1                2                      PESSOA FÍSICA DESOBRIGADA
# 2                3                    TITULAR OU SÓCIO DE EMPRESA
# 3                4  QUADRO SOCIETÁRIO OU ASSOCIADO DE COOPERATIVA
# 4                5                                    DE DECLARAR
#
#                                        question_text  \
# 0  Quem está obrigado a apresentar a Declaração d...
# 1  Pessoa física desobrigada pode apresentar a De...
# 2  Contribuinte que é titular ou sócio de empresa...
# 3  Contribuinte, que participou de quadro societá...
# 4  Contribuinte que constou como responsável pera...
#
#                                               answer  \
# 0  ['Está obrigada a apresentar a Declaração de A...
# 1  ['Sim. A pessoa física, ainda que desobrigada,...
# 2  ['Não, a menos que se enquadre nas hipóteses p...
# 3  ['Não, a menos que esteja obrigado a declarar ...
# 4  ['Esse contribuinte está obrigado a declarar c...
#
#                                       answer_cleaned  \
# 0  ['Está obrigada a apresentar a Declaração de A...
# 1  ['Sim. A pessoa física, ainda que desobrigada,...
# 2  ['Não, a menos que se enquadre nas hipóteses p...
# 3  ['Não, a menos que esteja obrigado a declarar ...
# 4  ['Esse contribuinte está obrigado a declarar c...
#
#                                           references linked_questions
# 0  Lei nº 9.250, de 26 de dezembro de 1995, art. ...              NaN
# 1  Instrução Normativa RFB nº 2.178, de 5 de març...   ['001', '174']
# 2  Instrução Normativa RFB nº 2.178, de 5 de març...          ['001']
# 3  Instrução Normativa RFB nº 2.178, de 5 de març...          ['001']
# 4  Instrução Normativa RFB nº 2.178, de 5 de març...          ['001']

# %%
data_csv = data_csv.drop(columns=['question_summary', 'answer', 'references', 'references', 'linked_questions'])
data_csv.head()
# Out:
#    question_number                                      question_text  \
# 0                1  Quem está obrigado a apresentar a Declaração d...
# 1                2  Pessoa física desobrigada pode apresentar a De...
# 2                3  Contribuinte que é titular ou sócio de empresa...
# 3                4  Contribuinte, que participou de quadro societá...
# 4                5  Contribuinte que constou como responsável pera...
#
#                                       answer_cleaned
# 0  ['Está obrigada a apresentar a Declaração de A...
# 1  ['Sim. A pessoa física, ainda que desobrigada,...
# 2  ['Não, a menos que se enquadre nas hipóteses p...
# 3  ['Não, a menos que esteja obrigado a declarar ...
# 4  ['Esse contribuinte está obrigado a declarar c...

# %%
from transformers import AutoTokenizer, AutoModel
import torch

# Carregando o tokenizer e o modelo Legal-BERT
tokenizer = AutoTokenizer.from_pretrained("stjiris/bert-large-portuguese-cased-legal-tsdae")
model = AutoModel.from_pretrained("stjiris/bert-large-portuguese-cased-legal-tsdae")

device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(29794, 1024, padding_idx=0)
#     (position_embeddings): Embedding(512, 1024)
#     (token_type_embeddings): Embedding(2, 1024)
#     (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-23): 24 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSdpaSelfAttention(
#             (query): Linear(in_features=1024, out_features=1024, bias=True)
#             (key): Linear(in_features=1024, out_features=1024, bias=True)
#             (value): Linear(in_features=1024, out_features=1024, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=4096, out_features=1024, bias=True)
#           (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=1024, out_features=1024, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
index = faiss.read_index("/content/drive/MyDrive/ProjetoFinal 2/faiss/faiss_index_v3.index")
index_acordaos = faiss.read_index("/content/drive/MyDrive/ProjetoFinal 2/faiss/faiss_index_acordaos_v3.index")

# %%
json_acordaos_path = '/content/drive/MyDrive/ProjetoFinal 2/json/acordaos.json'

with open(json_acordaos_path, 'r') as file:
    acordaos_json = json.load(file)

acordaos = list(acordaos_json.values())

json_normas_path = '/content/drive/MyDrive/ProjetoFinal 2/json/normas_full.json'

with open(json_normas_path, 'r') as file:
    normas_json = json.load(file)

normas = list(normas_json.values())

# %%
normas_acordaos_json = {**normas_json, **acordaos_json}

# %%
list(acordaos_json.items())[0]
# Out:
# ('10073720738201158_7133632.txt',
#  'DOCUMENTO VALIDADO \nMINISTÉRIO DA FAZENDA \nConselho Administrativo de Recursos Fiscais \nPROCESSO  \n10073.720738/2011-58  \nRESOLUÇÃO \n1202-000.270 – 1ª SEÇÃO/2ª CÂMARA/2ª TURMA ORDINÁRIA    \nSESSÃO DE \n16 de julho de 2024 \nRECURSO \nVOLUNTÁRIO \nRECORRENTE \nUNIMED RESENDE RJ COOPERATIVA DE TRABALHO MEDICO \nINTERESSADO \nFAZENDA NACIONAL \nAssunto: Conversão do Julgamento em Diligência \nRESOLUÇÃO \nVistos, relatados e discutidos os presentes autos. \nResolvem os membros do colegiado, por unanimidade de votos, converter o \njulgamento do recurso em diligência. \nSala de Sessões, em 16 de julho de 2024. \n \nAssinado Digitalmente \nMaurício Novaes Ferreira – Relator \n \nAssinado Digitalmente \nLeonardo de Andrade Couto – Presidente \n \nParticiparam da sessão de julgamento os julgadores Mauricio Novaes Ferreira, \nAndre Luis Ulrich Pinto, Ana Cecilia Lustosa da Cruz (suplente convocada), Roney Sandro Freire \nCorrea, Miriam Costa Faccin (suplente convocada), Leonardo de Andrade Couto (Presidente). \nAusentes o conselheiro Fellipe Honorio Rodrigues da Costa, substituído pela conselheira Ana \nCecilia Lustosa da Cruz, o conselheiro Marcelo Jose Luz de Macedo, substituído pela conselheira \nMiriam Costa Faccin. \n \n \nFl. 1573\nDF  CARF  MF\nOriginal\nDOCUMENTO VALIDADO \nRESOLUÇÃO  1202-000.270 – 1ª SEÇÃO/2ª CÂMARA/2ª TURMA ORDINÁRIA \n PROCESSO  10073.720738/2011-58 \n 2 \nRELATÓRIO \nTrata-se de recurso voluntário (fls. 362 a 404) interposto por UNIMED RESENDE RJ \nCOOPERATIVA DE TRABALHO MEDICO visando reformar o acórdão nº 12-67.970 (fls. 348 a 356), \nproferido pela 8ª Turma da Delegacia da Receita Federal do Brasil de Julgamento (DRJ) no Rio de \nJaneiro que julgou improcedente a impugnação apresentada e manteve a autuação fiscal. \nEste processo foi pautado em duas sessões anteriores em outra turma de \njulgamento deste Conselho, ocasiões em que os julgamentos foram convertidos em diligência. \nPor bem retratar os fatos processuais até então ocorridos, adoto o relatório \nintegrante da Resolução nº 1402-001.643, complementando-o em seguida com os eventos a ele \nposteriores: \n  \nRelatório  \n1. Trata-se de Recurso Voluntário (fls. 362-404 e docs. anexos) interposto em face \nde Acórdão n° 12-67.970, da 8ª Turma da DRJ/RJO (fls. 348-356), em sessão \nrealizada em 27 de agosto de 2014, por meio do qual o referido Órgão julgou \nimprocedente a Impugnação apresentada pela Contribuinte (fl. 165-189 e docs. \nanexos), de forma a manter o crédito tributário lançado em desfavor da \nImpugnante.  \nI. Auto de Infração (AI), Impugnação e DRJ  \n2. Por economia e celeridade processual, transcreve-se o relatório do Acórdão da \nDRJ de fl. 235-237.  \nTrata o presente processo da exigência fiscal formulada contra a \ninteressada acima identificada, por meio de lançamento de imposto sobre a \nrenda da pessoa jurídica (IRPJ) e contribuição social sobre o lucro líquido \n(CSLL), em valores respectivamente iguais a R$ 1.326.054,79 e R$ \n488.179,72. O lançamento refere-se aos anos-calendário 2006 e 2007. Aos \nvalores principais de ambos os tributos adicionou-se multa de ofício de 75% \ne juros de mora, com emprego da taxa Selic.  \nAutos de infração às fls. 135 e ss, onde consta o enquadramento legal da \ninfração, que fora descrita como “EXCLUSÕES/COMPENSAÇÕES NÃO \nAUTORIZADAS NA APURAÇÃO DO LUCRO REAL”, por ter realizado “Exclusão \nindevida de resultados positivos provenientes de operações com não \nassociados, conceituadas como atos não cooperativos, implicando redução \ndo lucro real”.  \nNo termo de verificação fiscal (TVF) de fls. 115 e ss, a fiscalização adicionou \nque “O problema reside no conceito de ato cooperativo adotado pela \nentidade, que difere essencialmente do conceito legal. Nos termos da lei \n5.764/71, que rege todo o sistema cooperativista, são atos cooperativos \nFl. 1574\nDF  CARF  MF\nOriginal\nDOCUMENTO VALIDADO \nRESOLUÇÃO  1202-000.270 – 1ª SEÇÃO/2ª CÂMARA/2ª TURMA ORDINÁRIA \n PROCESSO  10073 ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

delimiters = ["\nCAPÍTULO", "\nCapítulo", "\nSeção", "\nArt. ", "\n§", "\nI -", "\nII -", "\nIII -", "\nIV -", "\nV -", "\nVI -", "\nVII -", "\nVIII -", "\nIX -", "\nX -","\n"]

text_splitter = RecursiveCharacterTextSplitter(
    separators=delimiters,
    chunk_size=1000,  # Tamanho máximo do chunk em caracteres
    chunk_overlap=100  # Sobreposição entre chunks para contexto
)

chunks_normas = []
chunks_normas_acordaos = []
normas_acordaos = normas+acordaos

# Percorre cada item no JSON
for filename, doc in normas_json.items():
    # Remove a extensão ".txt" do nome do arquivo
    doc_name = filename.replace(".txt", "")

    # Divide o documento em chunks
    chunks = text_splitter.split_text(doc)

    # Adiciona o nome do documento a cada chunk
    for chunk in chunks:
        # Formata cada chunk com o nome do arquivo e o conteúdo
        chunk_with_name = f"{doc_name}: {chunk}"
        chunks_normas.append(chunk_with_name)

# Percorre cada item no JSON
for filename, doc in normas_acordaos_json.items():
    # Remove a extensão ".txt" do nome do arquivo
    doc_name = filename.replace(".txt", "")

    # Divide o documento em chunks
    chunks = text_splitter.split_text(doc)

    # Adiciona o nome do documento a cada chunk
    for chunk in chunks:
        # Formata cada chunk com o nome do arquivo e o conteúdo
        chunk_with_name = f"{doc_name}: {chunk}"
        chunks_normas_acordaos.append(chunk_with_name)

# %%
import requests
import torch
from transformers import AutoTokenizer, AutoModel
import pandas as pd
import numpy as np


def gerar_embedding(texto):
    # Tokenizar o texto
    inputs = tokenizer(texto, return_tensors="pt", truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)

    # Pooling: Média dos embeddings de cada token (desconsidera o token [CLS] e [SEP])
    embeddings = outputs.last_hidden_state
    embeddings = embeddings.mean(dim=1)  # Média ao longo dos tokens
    return embeddings.numpy()

def gerar_resposta_rag(pergunta, index, df, embedding_model, k=3):
    # Gerar o embedding da pergunta usando o BERTimbau
    pergunta_embedding = gerar_embedding(pergunta)

    # Recuperar as passagens mais próximas
    _, indices = index.search(np.array(pergunta_embedding, dtype=np.float32), k)

    # TROCAR chunks_normas ou chunks_normas_acordaos
    df_chunks_normas = pd.DataFrame({"resposta": chunks_normas_acordaos})
    # Obter os textos das passagens relevantes
    contextos = [df_chunks_normas.iloc[i]["resposta"] for i in indices[0]]
    contexto = " ".join(contextos)

    # Construir o prompt avançado
    prompt = f"""
      Você é um assistente virtual especializado em tributos brasileiros da Receita Federal. Responda à pergunta de forma completa e com base no contexto fornecido. Para garantir uma resposta precisa e fundamentada, siga estas etapas:

      Análise da Pergunta: Identifique o que a pergunta busca, considerando palavras-chave e aspectos específicos.

      Busca no Contexto: Examine o contexto em busca de trechos relevantes que se relacionem diretamente com a pergunta.

      Construção da Resposta:

      - Utilize as informações do contexto e organize a resposta de forma objetiva e precisa.
      - Cite diretamente as normas ou leis, utilizando as referências exatas sempre que possível, sem mencionar o termo "contexto", "referências", "fontes".
      - Informe sempre que possível, quando pertencer ao contexto, qual a forma de recolhimento que o imposto, se mensal obrigatório (carnê-leão) se recebidas de pessoa física ou de fonte no exterior, ou à retenção na fonte se pagas por pessoa jurídica, e ao ajuste na Declaração de Ajuste Anual (DAA).
      - Avaliação de Suficiência: Se o contexto não for suficiente para responder de forma fundamentada, responda apenas: "Estou aprendendo e no futuro poderei responder a essa pergunta."

      Regras a seguir:


      - Responda sempre de forma objetiva, sem trazer exemplos que não sejam diretamente relacionados com a pergunta.
      - Não inclua frases de interação direta com o usuário.
      - Caso o contexto não seja suficiente, declare que a resposta será disponibilizada futuramente.
      - Se a resposta já tiver sido respondida, não procure mais informações para complementar em outros contextos.
      - Sempre cite a norma e artigo que foi retirada a informação ao final da resposta em formato de lista, para o usuário consultar, ela geralmente está no começo dos contextos (serão enviados 3 em uma única string) antes dos ':' por exemplo: Lei nº 9.250, de 26 de dezembro de 1995, art. 25 ou Instrução Normativa RFB nº 2.178, de 5 de março de 2024, art. 2º.
      - Jamais cite parágrafos, incisos, §, alíneas e numerações, apenas normas e artigos nas respostas nem na lista.
      - Não mencione no meio das respostas nenhuma norma, artigo, parágrafos, incisos (§), alíneas e numerações, apenas na lista final de consulta do usuário.
      - Substitua RIR18 ou RIR/18, ou RIR/2018 ou RIR2018 quando for citar ele, o nome real que deve ser citado é Decreto Nº 9.580.
      - Para uso dos acórdãos, somente usar como exemplo para gerar respostas melhores, contudo sempre dentro do contexto tendo como base os artigos das normas mencionadas na resposta.
      - Igualmente sobre os acórdãos, somente informe na lista final sua numeração, exemplo: "Acórdão nº: 303-25.277 Nº do processo: 11065-001.472/87-94 Contribuinte: Bolivar & CIA”.
      - Não fale que consultou a normas ou artigos, apenas forneça a lista.

      Pergunta a ser respondida: "{pergunta}"

      Contexto: "{contexto}"
    """

    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model="gpt-4o-mini",
    )
    return chat_completion.choices[0].message.content, contextos

# Carregar o DataFrame com perguntas e respostas
# Certifique-se de que 'df' contém as colunas "pergunta" e "resposta"
df = data_csv[168:183]
#df = data_csv

# Adicionar uma nova coluna para salvar as respostas geradas
# MUDAR index ou index_acordaos
df[['resposta_rag', 'contexto']] = df["question_text"].apply(lambda pergunta: pd.Series(gerar_resposta_rag(pergunta, index_acordaos, df, model)))

# Salvar o DataFrame atualizado com as respostas RAG
# Out:
# <ipython-input-25-f473d1b8970f>:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['resposta_rag', 'contexto']] = df["question_text"].apply(lambda pergunta: pd.Series(gerar_resposta_rag(pergunta, index_acordaos, df, model)))
# <ipython-input-25-f473d1b8970f>:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['resposta_rag', 'contexto']] = df["question_text"].apply(lambda pergunta: pd.Series(gerar_resposta_rag(pergunta, index_acordaos, df, model)))

# %%
df
# Out:
#      question_number                                      question_text  \
# 168              206  Qual o tratamento tributário dos rendimentos d...
# 169              207  Qual é o tratamento tributário dos rendimentos...
# 170              208  Quando ocorre o fato gerador no caso de o alug...
# 171              209  O pai deu ao filho o usufruto de rendimentos d...
# 172              210  Como tratar os rendimentos produzidos por imóv...
# 173              211  Como deve ser tributada a quantia recebida por...
# 174              212  Como apurar o rendimento tributável de aluguel...
# 175              213  Os rendimentos oriundos de contrato de arrenda...
# 176              214  Qual é o tratamento tributário de rendimentos ...
# 177              215  As luvas e gratificações pagas ao locador são ...
# 178              216  A importância recebida pelo locatário a título...
# 179              217  Qual é o tratamento tributário do valor locati...
# 180              218  Os rendimentos oriundos da sublocação de imóve...
# 181              219  Como proceder quando o imóvel locado pertencer...
# 182              220  Podem os contribuintes casados no regime de co...
#
#                                         answer_cleaned  \
# 168  ['As quantias recebidas por pessoa física pela...
# 169  ['Preliminarmente, deve-se verificar se há aco...
# 170  ['O fato gerador ocorre no mês em que o locatá...
# 171  ['Se o usufruto constar de escritura pública a...
# 172  ['Esses rendimentos são tributáveis em nome de...
# 173  ['As quantias recebidas por pessoa física pela...
# 174  ['Tributa-se o valor recebido de aluguel subtr...
# 175  ['Os rendimentos provenientes de arrendamento ...
# 176  ['No caso de o locatário efetuar em juízo o de...
# 177  ['Sim. As luvas, prêmios, gratificações ou qua...
# 178  ['Sim. O valor da indenização recebida pelo lo...
# 179  ['O valor locativo de imóvel cedido a terceiro...
# 180  ['Sim. Os rendimentos recebidos pelo sublocado...
# 181  ['Quando o imóvel locado pertencer a mais de u...
# 182  ['Não, pois a opção, efetuada por ocasião da e...
#
#                                           resposta_rag  \
# 168  Os rendimentos de aluguel de imóvel localizado...
# 169  Os rendimentos de aluguel de imóvel localizado...
# 170  O fato gerador do imposto sobre a renda em rel...
# 171  Os rendimentos de aluguel de imóvel recebidos ...
# 172  Os rendimentos provenientes de um imóvel cujo ...
# 173  A tributação da quantia recebida por locação d...
# 174  Para apurar o rendimento tributável de aluguel...
# 175  Os rendimentos oriundos de contrato de arrenda...
# 176  Os rendimentos de aluguéis depositados em juíz...
# 177  As luvas e gratificações pagas ao locador são ...
# 178  A indenização recebida pelo locatário a título...
# 179  O tratamento tributário do valor locativo de u...
# 180  Os rendimentos oriundos da sublocação de imóve...
# 181  Quando o imóvel locado pertence a mais de uma ...
# 182  A resposta é não, os contribuintes casados no ...
#
#                                               contexto
# 168  [RIR2018: Art. 781. Compete ao procurador a re...
# 169  [RIR2018: Art. 781. Compete ao procurador a re...
# 170  [Instrução Normativa RFB nº 1.500: Seção VI\nD...
# 171  [Decreto nº 3.000: Art. 8º  Os cônjuges poderã...
# 172  [RIR2018: § 4º Na apuração do ganho de capital...
# 173  [Instrução Normativa RFB nº 1.500: Seção VI\nD...
# 174  [Instrução Normativa RFB nº 1.500: Seção VI\nD...
# 175  [13370721838202026_7150516: terceiros. \nO con...
# 176  [Instrução Normativa RFB nº 1.500: Art. 32. Co...
# 177  [Instrução Normativa RFB nº 1.500: Art. 32. Co...
# 178  [Instrução Normativa RFB nº 1.500: Art. 32. Co...
# 179  [Instrução Normativa RFB nº 1.500: Art. 32. Co...
# 180  [18470720505201184_7048661: § 1º A incidência ...
# 181  [Lei nº 10.406: Art. 1.415. Se o direito real ...
# 182  [RIR2018: Art. 7º Os cônjuges poderão optar pe...

# %%
df.to_excel("teste_total.xlsx", index = False)
files.download('teste_total.xlsx')
